# %%
using Catlab.Graphs, Catlab.Graphics

using Catlab.CategoricalAlgebra.FinSets
using Catlab.Theories

using DataStructures
using PrettyTables
PrettyTables.pretty_table(f::FinFunction, name::Symbol=:f) =
  pretty_table(OrderedDict(:x=>1:length(dom(f)), Symbol("$(name)(x)")=>collect(f)))

# %%
A = FinSet(4)
B = FinSet(3)
f = FinFunction([1,3,2,2], A, B)

to_graphviz(f, node_labels=true,
            graph_attrs=Dict(:splines=>"false", :rankdir => "TB"))
# Out:
# Catlab.Graphics.Graphviz.Graph("bipartite_graph", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Subgraph("cluster_nodes1", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1_1", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n1_2", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n1_3", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Node("n1_4", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1_2", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:style => "invis")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1_3", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:style => "invis")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_3", "", ""), Catlab.Graphics.Graphviz.NodeID("n1_4", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:style => "invis"))], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rank => "same"), OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Subgraph("cluster_nodes2", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n2_1", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2_2", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n2_3", OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2_1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_2", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:style => "invis")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2_2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_3", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:style => "invis"))], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rank => "same"), OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_1", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_3", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_2", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1_4", "", ""), Catlab.Graphics.Graphviz.NodeID("n2_2", "", "")], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false"))], OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "TB", :splines => "false"), OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height  ...

# %%
pretty_table(f)
# Out:
# ┌───────┬───────┐
# │     x │  f(x) │
# │ Int64 │ Int64 │
# ├───────┼───────┤
# │     1 │     1 │
# │     2 │     3 │
# │     3 │     2 │
# │     4 │     2 │
# └───────┴───────┘
